# %% [markdown]
# # ![](logo-itd.png)
#
# <div style = " Text-align: center">
#
# # Intligencia artificial
#
# ## covid 19
#
# ### Rodriguez Rivas Jose Gabriel
#
# ### Rubio Covarrubias Julio
#
# </div>

# %%
import pandas as pd

#create a pandas dataframe called "training" from the titanic-train.csv file
covid19 = pd.read_csv("200723COVID19MEXICO.csv", encoding = "unicode_escape")

# %%
covid19
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0               2020-07-23      1162e9       2       4           9     2
# 1               2020-07-23      0e50ac       2       4           9     2
# 2               2020-07-23      1dd91c       2       4           8     1
# 3               2020-07-23      1ad302       2       4          30     1
# 4               2020-07-23      1dd6f1       2       3          15     2
# ...                    ...         ...     ...     ...         ...   ...
# 879603          2020-07-23      1af1ae       1      12          19     2
# 879604          2020-07-23      193226       1       3          26     2
# 879605          2020-07-23      0fe94e       2      12          24     1
# 879606          2020-07-23      118851       2      12           9     1
# 879607          2020-07-23      0a6c4c       1       4          11     1
#
#         ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# ...

# %%
covid19['Sobrevivio'] = covid19['FECHA_DEF'].apply(lambda toLabel: 0 if toLabel =='9999-99-99' else 1)

# %%
covid19
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0               2020-07-23      1162e9       2       4           9     2
# 1               2020-07-23      0e50ac       2       4           9     2
# 2               2020-07-23      1dd91c       2       4           8     1
# 3               2020-07-23      1ad302       2       4          30     1
# 4               2020-07-23      1dd6f1       2       3          15     2
# ...                    ...         ...     ...     ...         ...   ...
# 879603          2020-07-23      1af1ae       1      12          19     2
# 879604          2020-07-23      193226       1       3          26     2
# 879605          2020-07-23      0fe94e       2      12          24     1
# 879606          2020-07-23      118851       2      12           9     1
# 879607          2020-07-23      0a6c4c       1       4          11     1
#
#         ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OBESIDAD  \
# ...

# %%
covid19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879608 entries, 0 to 879607
# Data columns (total 36 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FECHA_ACTUALIZACION  879608 non-null  object
#  1   ID_REGISTRO          879608 non-null  object
#  2   ORIGEN               879608 non-null  int64
#  3   SECTOR               879608 non-null  int64
#  4   ENTIDAD_UM           879608 non-null  int64
#  5   SEXO                 879608 non-null  int64
#  6   ENTIDAD_NAC          879608 non-null  int64
#  7   ENTIDAD_RES          879608 non-null  int64
#  8   MUNICIPIO_RES        879608 non-null  int64
#  9   TIPO_PACIENTE        879608 non-null  int64
#  10  FECHA_INGRESO        879608 non-null  object
#  11  FECHA_SINTOMAS       879608 non-null  object
#  12  FECHA_DEF            879608 non-null  object
#  13  INTUBADO             879608 non-null  int64
#  14  NEUMONIA             879608 non-null  int64
# ...

# %%
y_target = covid19["Sobrevivio"].values

# %%
columns = ["UCI","TABAQUISMO","RENAL_CRONICA","OBESIDAD","SEXO", "EDAD", "EMBARAZO", "INTUBADO" ,"NEUMONIA", "DIABETES","EPOC","ASMA","INMUSUPR","HIPERTENSION","CARDIOVASCULAR" ]
#create the variable to hold the features that the classifier will use
X_input = covid19[list(columns)].values

# %%
#import the tree module from the sklearn library
from sklearn import tree
#create clf_train as a decision tree classifier object
clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)
#train the model using the fit() method of the decision tree object. 
#Supply the method with the input variable X_input and the target variable y_target
clf_train = clf_train.fit(X_input, y_target)

# %%
clf_train.score(X_input,y_target)
# Out:
# 0.9425641876836045

# %%
clasificacion=['Sobrevivio', 'NO Sobrevivio']

# %%
covid19
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0               2020-07-23      1162e9       2       4           9     2
# 1               2020-07-23      0e50ac       2       4           9     2
# 2               2020-07-23      1dd91c       2       4           8     1
# 3               2020-07-23      1ad302       2       4          30     1
# 4               2020-07-23      1dd6f1       2       3          15     2
# ...                    ...         ...     ...     ...         ...   ...
# 879603          2020-07-23      1af1ae       1      12          19     2
# 879604          2020-07-23      193226       1       3          26     2
# 879605          2020-07-23      0fe94e       2      12          24     1
# 879606          2020-07-23      118851       2      12           9     1
# 879607          2020-07-23      0a6c4c       1       4          11     1
#
#         ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OBESIDAD  \
# ...

# %%
import sklearn
#from sklearn.externals.six import StringIO
with open("covid.dot", 'w') as f:
 f = tree.export_graphviz(Train, out_file=f, feature_names=columns, class_names=clasificacion)

# %%
# !dot -Tpng covid.dot -o covid.png

# %%
from IPython.display import Image

Image("covid.png")

# %% [markdown]
# #### Conclusion

# %% [markdown]
# En general piesno que esta es una practica muy interesante para conocer cuantos no sobrevivientes tuvo el esta pandemia lo cual dicha tabla no nos otrograba dicho dato asi que sacamos este dato con la fehca de defuncion de la persona
